# %%
import pandas as pd

# %%
# Load dataset
file_path = 'data/netflix_titles.csv'
netflix_data = pd.read_csv(file_path)
netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Remove all rows where the 'director' column has missing values.
drop_missing_director_df = netflix_data.dropna(subset='director')

# Report the number of rows left in the DataFrame.
print(f'There are {len(drop_missing_director)} rows left in the DataFrame')
drop_missing_director_df
# Out:
# There are 6173 rows left in the DataFrame
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...

# %%
# Starting from the original DataFrame, remove all rows where either 'director' or 'cast' columns (or both) have missing values.
remove_missing_director_cast_df = netflix_data.dropna(subset=['director', 'cast'], how='any')

# Report the number of rows left in the DataFrame after this operation.
print(f'There are {len(remove_missing_director_cast_df)} rows left in the DataFrame')
remove_missing_director_cast_df
# Out:
# There are 5700 rows left in the DataFrame
#      show_id     type                             title  \
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# 8         s9  TV Show     The Great British Baking Show
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...

# %%
# Create a new DataFrame from the original where all columns with any missing values are removed.
any_missing_values_df = netflix_data.dropna()
any_missing_values_df

# Report the number of columns in this new DataFrame and how many columns were removed from the original DataFrame.
num_cols = any_missing_values_df.count()
num_rows_removed = len(netflix_data) - len(any_missing_values_df)

print(f'There are {len(num_cols)} columns and {num_rows_removed} rows were removed from the original DataFrame.')
any_missing_values_df
# Out:
# There are 12 columns and 3475 rows were removed from the original DataFrame.
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
# ...
